# %% [markdown]
# # Causal Learning on Breast Cancer Dataset

# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

import warnings
warnings.filterwarnings('ignore')

# %%
## Scientific Modules
from sklearn.model_selection import train_test_split

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from causalnex.discretiser import Discretiser
from causalnex.structure import DAGRegressor
from causalnex.inference import InferenceEngine
from causalnex.network import BayesianNetwork
from causalnex.network.sklearn import BayesianNetworkClassifier
from causalnex.structure.notears import from_pandas
from causalnex.utils.network_utils import get_markov_blanket


from causalnex.structure.notears import from_pandas, from_pandas_lasso
from causalnex.discretiser.discretiser_strategy import ( DecisionTreeSupervisedDiscretiserMethod )

from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score, f1_score, accuracy_score

from causalnex.plots import plot_structure, NODE_STYLE, EDGE_STYLE
from IPython.display import Markdown, display, Image, display_html
# Out:
# WARNING:root:MDLP was not imported successfully

# %%
# Pandas configration
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Custom Modules

from myscripts import file
from myscripts import utils

# %% [markdown]
# ### Read Dataset

# %%
file_name = '../data/clean_breast_cancer.csv'
data = file.read_csv(file_name)

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         0.118400           0.22862         0.28241              0.14710
# 1         0.084740           0.07864         0.08690              0.07017
# 2         0.109600           0.15990         0.19740              0.12790
# 3         0.133695           0.22862         0.24140              0.10520
# 4         0.100300           0.13280         0.19800              0.10430
#
# ...

# %% [markdown]
# ### change label of diagnosis column
# This will help us prepare our dataset for Machine learning

# %%
data['diagnosis'] = data['diagnosis'].apply(utils.labeler)

# %%
data.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         0.118400           0.22862         0.28241              0.14710
# 1         0.084740           0.07864         0.08690              0.07017
# 2         0.109600           0.15990         0.19740              0.12790
# 3         0.133695           0.22862         0.24140              0.10520
# 4         0.100300           0.13280         0.19800              0.10430
#
# ...

# %% [markdown]
# ### Train Test Split

# %%
# X = data.drop(['id', 'diagnosis'], axis=1)
# y = data['diagnosis']

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
train, test = train_test_split(data, test_size=0.3)
train.head()
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 343    898431          1       19.680         21.68          129.90
# 520    917092          0        9.295         13.90           59.96
# 64   85922302          1       12.680         23.84           82.69
# 421    906564          0       14.690         13.98           98.22
# 16     848406          1       14.680         20.13           94.74
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 343     1194.0         0.097970            0.1339         0.18630
# 520      257.8         0.133695            0.1225         0.03332
# 64       499.0         0.112200            0.1262         0.11280
# 421      656.1         0.103100            0.1836         0.14500
# 16       684.5         0.098670            0.0720         0.07395
#
#      concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  \
# 343              0.11030         0.2082                 0.05715     0.6226
# ...

# %% [markdown]
# ### Create a causal graph using all training data and get the insights (this will be considered the ground truth)

# %%
# ! pip install pygraphviz

# %%
sm = from_pandas(data, w_threshold=0.8)
viz = plot_structure(
    sm,
    graph_attributes={"scale": "2.0", 'size':2.5},
    all_node_attributes=NODE_STYLE.WEAK,
    all_edge_attributes=EDGE_STYLE.WEAK)
Image(viz.draw(format='png'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/networkx/drawing/nx_agraph.py in to_agraph(N)
#     129     try:
# --> 130         import pygraphviz
#     131     except ImportError as e:
#
# ModuleNotFoundError: No module named 'pygraphviz'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/causalnex/plots/plots.py in plot_structure(sm, prog, all_node_attributes, all_edge_attributes, node_attributes, edge_attributes, graph_attributes)
#     109     try:
# --> 110         a_graph = nx.nx_agraph.to_agraph(_sm)
#     111     except ImportError as error_msg:
#
# /opt/anaconda3/lib/python3.8/site-packages/networkx/drawing/nx_agraph.py in to_agraph(N)
#     131     except ImportError as e:
# ...

# %% [markdown]
# ### Create new causal graphs using increasing fractions of the data and compare with the ground truth graph
#     a. The comparison can be done with a Jaccard Similarity Index, measuring
#         the intersection and union of the graph edges

# %% [markdown]
# ### After reaching a stable causal graph, select only variables that point directly to the target variable

# %% [markdown]
# ### Train one model using all variables and another using only the variables selected by the graph

# %% [markdown]
# ### Measure how much each of the models overfit the hold-out set created in step 1.
